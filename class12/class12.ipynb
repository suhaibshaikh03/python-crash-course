# %%
class StudentCard():
    def __init__(self, roll_no:int,name:str,age:int) -> None:
        if age < 18 or age > 60:
            raise StudentAgeError("You are not eligible for this program")
        self.roll_no = roll_no
        self.name = name
        self.age = age



class StudentAgeError(Exception):#custom error class
    pass
student1 = StudentCard(1,"Qasim",13)
print(student1.name, student1.roll_no, student1.age)

student2 = StudentCard(1,"hammad",89)
print(student2.name, student2.roll_no, student2.age)

# custom error generated
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[3], line 13
#      11 class StudentAgeError(Exception):#custom error class
#      12     pass
# ---> 13 student1 = StudentCard(1,"Qasim",13)
#      14 print(student1.name, student1.roll_no, student1.age)
#      16 student2 = StudentCard(1,"hammad",89)
#
# Cell In[3], line 4, in StudentCard.__init__(self, roll_no, name, age)
#       2 def __init__(self, roll_no:int,name:str,age:int) -> None:
#       3     if age < 18 or age > 60:
# ----> 4         raise StudentAgeError("You are not eligible for this program")
#       5     self.roll_no = roll_no
#       6     self.name = name
#
# StudentAgeError: You are not eligible for this program

# %% [markdown]
# # File Handling

# %% [markdown]
# <img src="https://net-informations.com/python/file/img/modes.png">

# %%
open("./abc.txt")
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='cp1252'>

# %%
data = open("./abc.txt")
data
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='cp1252'>

# %%
[i for i in dir(data) if "__" not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
type(data)
# Out:
# _io.TextIOWrapper

# %%
from typing import TextIO
data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())#reads data
# Out:
# line 1
# line 2

# %%
from typing import TextIO
data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())#reads data
data.close() # close connectivity
# Out:
# line 1
# line 2

# %%
with open("./abc.txt") as file:
    print(type(file))
    print(file.read())

print("pakistan zindabad!")
# Out:
# <class '_io.TextIOWrapper'>
# line 1
# line 2
# pakistan zindabad!

# %%
with open("./abc.txt") as file: #type : TextIO
    print(type(file))
    print(file.readline()) # read only one line(firstline)
    print(file.readline()) # line 2
# Out:
# <class '_io.TextIOWrapper'>
# line 1
#
# line 2

# %%
with open("./abc.txt") as file: #type : TextIO
    print(type(file))
    print(file.readline(),end="") # read only one line(firstline)
    print(file.readline(),end="") # line 2
# Out:
# <class '_io.TextIOWrapper'>
# line 1
# line 2

# %%
with open("./abc.txt") as file: #type : TextIO
    print(type(file))
    print(file.readlines())
# Out:
# <class '_io.TextIOWrapper'>
# ['line 1\n', 'line 2\n', 'line 3\n', 'line 4\n', 'line 5']

# %%
with open("./abc.txt") as file: #type : TextIO
    print(type(file))
    print(file.readline()[:3])
# Out:
# <class '_io.TextIOWrapper'>
# ['line 1\n', 'line 2\n', 'line 3\n']

# %%
with open("./abc.txt",'r') as file: #type : TextIO
    print(type(file))
    print(file.readlines()[:3])
# Out:
# <class '_io.TextIOWrapper'>
# ['line 1\n', 'line 2\n', 'line 3\n']

# %%
with open("./abc.txt",'r') as file: #type : TextIO
    print(file.read())
    file.write("Pakistan Zindabad")
    #error
# Out:
# line 1
# line 2
# line 3
# line 4
# line 5
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[25], line 3
#       1 with open("./abc.txt",'r') as file: #type : TextIO
#       2     print(file.read())
# ----> 3     file.write("Pakistan Zindabad")
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt",'w') as file: #type : TextIO
    print(file.read())
    file.write("Pakistan Zindabad")
    #error
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[26], line 2
#       1 with open("./abc.txt",'w') as file: #type : TextIO
# ----> 2     print(file.read())
#       3     file.write("Pakistan Zindabad")
#       4     #error
#
# UnsupportedOperation: not readable

# %%
with open("./abc1.txt",'w') as file: #type : TextIO
    file.write("Pakistan Zindabad")
    #error

# %%
with open("./abc1.txt",'r+') as file: #type : TextIO
    
    print(file.read())
    file.write("we love our country")
    #error
# Out:
# pakistan zindabad

# %%
with open("./abc1.txt",'r+') as file: #type : TextIO
    print(file.read())
    file.write("we love our country")
    print("After",file.read())

    #error
# Out:
# pakistan zindabad
# After

# %%
with open("./abc1.txt",'r+') as file: #type : TextIO
    print(file.read())
    file.write("we love our country")
    file.seek(0)
    print("After",file.read())

    #error
# Out:
# pakistan zindabad
# After pakistan zindabadwe love our country

# %% [markdown]
# ## Now change mode

# %%
with open("./abc2.txt",'r') as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 with open("./abc2.txt",'r') as file:
#       2     print(file.read())
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './abc2.txt'

# %%
with open("./abc2.txt",'w') as file:
   # print(file.read())
   file.write("Pakistan")

# if file exist then it overwrites the text
# if file does not exist then it will create new file

# %%
with open("./abc3.txt",'a') as file:
        file.write("Pakistan")

# %%
with open("./abc3.txt",'a') as file:
        file.write("line2")

# %%
with open("./abc3.txt",'a') as file:
        file.write("line3")

# %%
with open("./abc4.txt",'x') as file:
        file.write("Pakistan")
# if file does not exist then it will create new file
# always new file

# %%
with open("./abc4.txt",'x') as file:
        file.write("Pakistan")
#error
# if file does not exist then it will create new file
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 with open("./abc4.txt",'x') as file:
#       2         file.write("Pakistan")
#       3 #error
#       4 # if file does not exist then it will create new file
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: './abc4.txt'

# %%
with open("./abc4.txt",'rb+') as file:
        print(file.read())
# if file does not exist then it will create new file
# Out:
# b'Pakistan'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # read some real world data files
# * image
# * csv
# * live camera

# %%
import pandas as pd
df: pd.DataFrame = pd.read_csv("./data.csv") 
df
# Out:
#    id            name education
# 0   1         Sir Zia    Master
# 1   2        Sir Inam    Master
# 2   3  Muhammad Qasim      MSDS

# %%
import pandas as pd
df : pd.DataFrame = pd.read_excel("./Book1.csv.xlsx")
df
# Out:
#     id            name education
# 0  1.0         Sir Zia    Master
# 1  2.0        Sir Inam    Master
# 2  3.0  Muhammad Qasim      MSDS
# 3  4.0        Dr.Noman       PHD
# 4  NaN             NaN         s

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("img1.jpeg") # convert into numpy array
plt.imshow(img)
